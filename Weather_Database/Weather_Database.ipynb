# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 706

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | luau
# Processing Record 2 of Set 1 | aklavik
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | oktyabrskoye
# Processing Record 5 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 1 | victoria
# Processing Record 7 of Set 1 | darhan
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | provideniya
# Processing Record 10 of Set 1 | pisco
# Processing Record 11 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 1 | moramanga
# Processing Record 13 of Set 1 | cherskiy
# Processing Record 14 of Set 1 | babanusah
# City not found. Skipping...
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | kavaratti
# Processing Record 17 of Set 1 | great yarmouth
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | betare oya
# Processing Record 20 of Set 1 | longyearbyen
# Processing Record 21 of Set 1 | tamala
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | nemuro
# Processing Record 25 of Set 1 | road town
# Processing Record 26 of Set 1 | paragominas
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | kintampo
# Processing Record 29 of Set 1 | lebu
# Processing Record 30 of Set 1 | salalah
# Processing Record 31 of Set 1 | ust-tsilma
# Processing Record 32 of Set 1 | raudeberg
# Processing Record 33 of Set 1 | kruisfontein
# Processing Record 34 of Set 1 | angoram
# Processing Record 35 of Set 1 | witrivier
# City not found. Skipping...
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | skiros
# City not found. Skipping...
# Processing Record 38 of Set 1 | george town
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | buala
# Processing Record 41 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | bafoulabe
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | castro
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | trondheim
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | kifri
# Processing Record 1 of Set 2 | pevek
# Processing Record 2 of Set 2 | sao filipe
# Processing Record 3 of Set 2 | iqaluit
# Processing Record 4 of Set 2 | carutapera
# Processing Record 5 of Set 2 | ouango
# Processing Record 6 of Set 2 | leningradskiy
# Processing Record 7 of Set 2 | cidreira
# Processing Record 8 of Set 2 | diego de almagro
# Processing Record 9 of Set 2 | tabou
# Processing Record 10 of Set 2 | luderitz
# Processing Record 11 of Set 2 | san andres
# Processing Record 12 of Set 2 | mahebourg
# Processing Record 13 of Set 2 | saint-augustin
# Processing Record 14 of Set 2 | tuktoyaktuk
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | saint george
# Processing Record 17 of Set 2 | guanica
# Processing Record 18 of Set 2 | talawdi
# City not found. Skipping...
# Processing Record 19 of Set 2 | kushima
# Processing Record 20 of Set 2 | kempele
# Processing Record 21 of Set 2 | la ronge
# Processing Record 22 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 2 | hilo
# Processing Record 24 of Set 2 | namwala
# Processing Record 25 of Set 2 | huarmey
# Processing Record 26 of Set 2 | souillac
# Processing Record 27 of Set 2 | jadu
# Processing Record 28 of Set 2 | east london
# Processing Record 29 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 30 of Set 2 | berlevag
# Processing Record 31 of Set 2 | busselton
# Processing Record 32 of Set 2 | shakiso
# Processing Record 33 of Set 2 | albany
# Processing Record 34 of Set 2 | atuona
# Processing Record 35 of Set 2 | thompson
# Processing Record 36 of Set 2 | sorland
# Processing Record 37 of Set 2 | northam
# Processing Record 38 of Set 2 | hermanus
# Processing Record 39 of Set 2 | baruun-urt
# Processing Record 40 of Set 2 | macusani
# Processing Record 41 of Set 2 | arraial do cabo
# Processing Record 42 of Set 2 | tuatapere
# Processing Record 43 of Set 2 | grindavik
# Processing Record 44 of Set 2 | bambous virieux
# Processing Record 45 of Set 2 | vaini
# Processing Record 46 of Set 2 | mareeba
# Processing Record 47 of Set 2 | meulaboh
# Processing Record 48 of Set 2 | isla mujeres
# Processing Record 49 of Set 2 | hithadhoo
# Processing Record 50 of Set 2 | shugurovo
# Processing Record 1 of Set 3 | porvoo
# Processing Record 2 of Set 3 | barrow
# Processing Record 3 of Set 3 | palmer
# Processing Record 4 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 3 | namibe
# Processing Record 6 of Set 3 | kavieng
# Processing Record 7 of Set 3 | kudahuvadhoo
# Processing Record 8 of Set 3 | marystown
# Processing Record 9 of Set 3 | katsuura
# Processing Record 10 of Set 3 | laguna
# Processing Record 11 of Set 3 | ancud
# Processing Record 12 of Set 3 | beloha
# Processing Record 13 of Set 3 | cap malheureux
# Processing Record 14 of Set 3 | saskylakh
# Processing Record 15 of Set 3 | nishihara
# Processing Record 16 of Set 3 | humaita
# Processing Record 17 of Set 3 | gorontalo
# Processing Record 18 of Set 3 | clermont
# Processing Record 19 of Set 3 | quata
# Processing Record 20 of Set 3 | anori
# Processing Record 21 of Set 3 | inuvik
# Processing Record 22 of Set 3 | burnie
# Processing Record 23 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 25 of Set 3 | lavumisa
# Processing Record 26 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 3 | kadykchan
# City not found. Skipping...
# Processing Record 28 of Set 3 | bokspits
# City not found. Skipping...
# Processing Record 29 of Set 3 | cabo san lucas
# Processing Record 30 of Set 3 | acarau
# Processing Record 31 of Set 3 | auki
# Processing Record 32 of Set 3 | chibuto
# Processing Record 33 of Set 3 | dikson
# Processing Record 34 of Set 3 | waipawa
# Processing Record 35 of Set 3 | vinces
# Processing Record 36 of Set 3 | sabha
# Processing Record 37 of Set 3 | pandan
# Processing Record 38 of Set 3 | port-cartier
# Processing Record 39 of Set 3 | severo-kurilsk
# Processing Record 40 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 3 | takoradi
# Processing Record 42 of Set 3 | omboue
# Processing Record 43 of Set 3 | gwadar
# Processing Record 44 of Set 3 | porto novo
# Processing Record 45 of Set 3 | mahaicony
# City not found. Skipping...
# Processing Record 46 of Set 3 | khormuj
# City not found. Skipping...
# Processing Record 47 of Set 3 | khatanga
# Processing Record 48 of Set 3 | leshukonskoye
# Processing Record 49 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 3 | maniitsoq
# Processing Record 1 of Set 4 | lotoshino
# Processing Record 2 of Set 4 | necochea
# Processing Record 3 of Set 4 | pineville
# Processing Record 4 of Set 4 | lagoa
# Processing Record 5 of Set 4 | mar del plata
# Processing Record 6 of Set 4 | champerico
# Processing Record 7 of Set 4 | paoua
# Processing Record 8 of Set 4 | pingdu
# Processing Record 9 of Set 4 | qaanaaq
# Processing Record 10 of Set 4 | colares
# Processing Record 11 of Set 4 | zhigansk
# Processing Record 12 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 4 | port elizabeth
# Processing Record 14 of Set 4 | carnarvon
# Processing Record 15 of Set 4 | port hardy
# Processing Record 16 of Set 4 | saint-pierre
# Processing Record 17 of Set 4 | mansehra
# Processing Record 18 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 19 of Set 4 | shilka
# Processing Record 20 of Set 4 | bengkulu
# Processing Record 21 of Set 4 | ponta do sol
# Processing Record 22 of Set 4 | yaan
# Processing Record 23 of Set 4 | luanda
# Processing Record 24 of Set 4 | alofi
# Processing Record 25 of Set 4 | santa lucia
# Processing Record 26 of Set 4 | beringovskiy
# Processing Record 27 of Set 4 | sitka
# Processing Record 28 of Set 4 | jinchengjiang
# City not found. Skipping...
# Processing Record 29 of Set 4 | bethel
# Processing Record 30 of Set 4 | upington
# Processing Record 31 of Set 4 | gaurela
# Processing Record 32 of Set 4 | ovsyanka
# Processing Record 33 of Set 4 | faanui
# Processing Record 34 of Set 4 | san cristobal
# Processing Record 35 of Set 4 | norman wells
# Processing Record 36 of Set 4 | rolla
# Processing Record 37 of Set 4 | grandview
# Processing Record 38 of Set 4 | alice springs
# Processing Record 39 of Set 4 | tazovskiy
# Processing Record 40 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 4 | taylorville
# Processing Record 42 of Set 4 | tasiilaq
# Processing Record 43 of Set 4 | the pas
# Processing Record 44 of Set 4 | sao carlos
# Processing Record 45 of Set 4 | saint-philippe
# Processing Record 46 of Set 4 | westport
# Processing Record 47 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 4 | san patricio
# Processing Record 49 of Set 4 | portland
# Processing Record 50 of Set 4 | pacific grove
# Processing Record 1 of Set 5 | alugan
# Processing Record 2 of Set 5 | killarney
# Processing Record 3 of Set 5 | askiz
# Processing Record 4 of Set 5 | padang
# Processing Record 5 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 6 of Set 5 | puerto ayora
# Processing Record 7 of Set 5 | suntar
# Processing Record 8 of Set 5 | medina
# Processing Record 9 of Set 5 | dongtai
# Processing Record 10 of Set 5 | lumding
# Processing Record 11 of Set 5 | fairbanks
# Processing Record 12 of Set 5 | esperance
# Processing Record 13 of Set 5 | dezhou
# Processing Record 14 of Set 5 | oranjemund
# Processing Record 15 of Set 5 | urumqi
# Processing Record 16 of Set 5 | strezhevoy
# Processing Record 17 of Set 5 | vanimo
# Processing Record 18 of Set 5 | kamaishi
# Processing Record 19 of Set 5 | surt
# Processing Record 20 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 5 | jimenez
# Processing Record 22 of Set 5 | fortuna
# Processing Record 23 of Set 5 | new norfolk
# Processing Record 24 of Set 5 | awbari
# Processing Record 25 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 26 of Set 5 | torbat-e jam
# Processing Record 27 of Set 5 | airai
# Processing Record 28 of Set 5 | chiredzi
# Processing Record 29 of Set 5 | springhill
# Processing Record 30 of Set 5 | jalu
# Processing Record 31 of Set 5 | antsohihy
# Processing Record 32 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 5 | chalus
# Processing Record 34 of Set 5 | svetlogorsk
# Processing Record 35 of Set 5 | constitucion
# Processing Record 36 of Set 5 | nikolskoye
# Processing Record 37 of Set 5 | jiayuguan
# Processing Record 38 of Set 5 | genhe
# Processing Record 39 of Set 5 | san quintin
# Processing Record 40 of Set 5 | brattleboro
# Processing Record 41 of Set 5 | pizarro
# Processing Record 42 of Set 5 | hamilton
# Processing Record 43 of Set 5 | pundaguitan
# Processing Record 44 of Set 5 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 45 of Set 5 | hasaki
# Processing Record 46 of Set 5 | moron
# Processing Record 47 of Set 5 | lujan
# Processing Record 48 of Set 5 | pringsewu
# Processing Record 49 of Set 5 | nelson bay
# Processing Record 50 of Set 5 | mogadishu
# Processing Record 1 of Set 6 | halifax
# Processing Record 2 of Set 6 | tura
# Processing Record 3 of Set 6 | oudtshoorn
# Processing Record 4 of Set 6 | bathsheba
# Processing Record 5 of Set 6 | san isidro
# Processing Record 6 of Set 6 | port-gentil
# Processing Record 7 of Set 6 | ahipara
# Processing Record 8 of Set 6 | boa vista
# Processing Record 9 of Set 6 | kloulklubed
# Processing Record 10 of Set 6 | kedougou
# Processing Record 11 of Set 6 | talaya
# Processing Record 12 of Set 6 | bahia blanca
# Processing Record 13 of Set 6 | digby
# Processing Record 14 of Set 6 | goderich
# Processing Record 15 of Set 6 | barcelona
# Processing Record 16 of Set 6 | zyryanovsk
# Processing Record 17 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 19 of Set 6 | talnakh
# Processing Record 20 of Set 6 | torbay
# Processing Record 21 of Set 6 | port lincoln
# Processing Record 22 of Set 6 | vao
# Processing Record 23 of Set 6 | whyalla
# Processing Record 24 of Set 6 | coihaique
# Processing Record 25 of Set 6 | altay
# Processing Record 26 of Set 6 | georgetown
# Processing Record 27 of Set 6 | zelenogorskiy
# Processing Record 28 of Set 6 | bartica
# Processing Record 29 of Set 6 | mount gambier
# Processing Record 30 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 6 | lorengau
# Processing Record 32 of Set 6 | poum
# Processing Record 33 of Set 6 | general roca
# Processing Record 34 of Set 6 | lompoc
# Processing Record 35 of Set 6 | ucluelet
# Processing Record 36 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 6 | dahegam
# Processing Record 38 of Set 6 | dingle
# Processing Record 39 of Set 6 | mimongo
# Processing Record 40 of Set 6 | morro bay
# Processing Record 41 of Set 6 | ardesen
# Processing Record 42 of Set 6 | tiksi
# Processing Record 43 of Set 6 | ribeira grande
# Processing Record 44 of Set 6 | ilulissat
# Processing Record 45 of Set 6 | lekoni
# Processing Record 46 of Set 6 | nome
# Processing Record 47 of Set 6 | kahului
# Processing Record 48 of Set 6 | hofn
# Processing Record 49 of Set 6 | vyazemskiy
# Processing Record 50 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 7 | caravelas
# Processing Record 2 of Set 7 | charlestown
# Processing Record 3 of Set 7 | tromso
# Processing Record 4 of Set 7 | pamekasan
# Processing Record 5 of Set 7 | killybegs
# Processing Record 6 of Set 7 | kimbe
# Processing Record 7 of Set 7 | leh
# Processing Record 8 of Set 7 | aporawan
# City not found. Skipping...
# Processing Record 9 of Set 7 | wanning
# Processing Record 10 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 7 | dongning
# Processing Record 12 of Set 7 | lokosovo
# Processing Record 13 of Set 7 | jacarau
# Processing Record 14 of Set 7 | kondagaon
# Processing Record 15 of Set 7 | south lake tahoe
# Processing Record 16 of Set 7 | gravina in puglia
# Processing Record 17 of Set 7 | acapulco
# Processing Record 18 of Set 7 | iberia
# Processing Record 19 of Set 7 | arroyo
# Processing Record 20 of Set 7 | sobolevo
# Processing Record 21 of Set 7 | klaksvik
# Processing Record 22 of Set 7 | komsomolskiy
# Processing Record 23 of Set 7 | jiwani
# Processing Record 24 of Set 7 | ngunguru
# Processing Record 25 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 26 of Set 7 | kirakira
# Processing Record 27 of Set 7 | hailar
# Processing Record 28 of Set 7 | colac
# Processing Record 29 of Set 7 | coruripe
# Processing Record 30 of Set 7 | coquimbo
# Processing Record 31 of Set 7 | chimbote
# Processing Record 32 of Set 7 | mercedes
# Processing Record 33 of Set 7 | port hedland
# Processing Record 34 of Set 7 | beira
# Processing Record 35 of Set 7 | port macquarie
# Processing Record 36 of Set 7 | sangar
# Processing Record 37 of Set 7 | burica
# City not found. Skipping...
# Processing Record 38 of Set 7 | paraiso
# Processing Record 39 of Set 7 | lata
# Processing Record 40 of Set 7 | kodiak
# Processing Record 41 of Set 7 | barra patuca
# Processing Record 42 of Set 7 | clyde river
# Processing Record 43 of Set 7 | awjilah
# Processing Record 44 of Set 7 | guerrero negro
# Processing Record 45 of Set 7 | kaura namoda
# Processing Record 46 of Set 7 | acari
# Processing Record 47 of Set 7 | brae
# Processing Record 48 of Set 7 | linxia
# Processing Record 49 of Set 7 | kaitangata
# Processing Record 50 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 8 | geraldton
# Processing Record 2 of Set 8 | viedma
# Processing Record 3 of Set 8 | wewak
# Processing Record 4 of Set 8 | turan
# Processing Record 5 of Set 8 | dunkwa
# Processing Record 6 of Set 8 | heyang
# Processing Record 7 of Set 8 | lavrentiya
# Processing Record 8 of Set 8 | esso
# Processing Record 9 of Set 8 | antalaha
# Processing Record 10 of Set 8 | koudougou
# Processing Record 11 of Set 8 | touros
# Processing Record 12 of Set 8 | saldanha
# Processing Record 13 of Set 8 | pangody
# Processing Record 14 of Set 8 | brookhaven
# Processing Record 15 of Set 8 | honiara
# Processing Record 16 of Set 8 | corn island
# Processing Record 17 of Set 8 | thinadhoo
# Processing Record 18 of Set 8 | mildura
# Processing Record 19 of Set 8 | bossangoa
# Processing Record 20 of Set 8 | ksenyevka
# City not found. Skipping...
# Processing Record 21 of Set 8 | sheridan
# Processing Record 22 of Set 8 | okhotsk
# Processing Record 23 of Set 8 | batagay-alyta
# Processing Record 24 of Set 8 | sao joao da barra
# Processing Record 25 of Set 8 | west bay
# Processing Record 26 of Set 8 | puerto ayacucho
# Processing Record 27 of Set 8 | rumonge
# Processing Record 28 of Set 8 | tawau
# Processing Record 29 of Set 8 | kashan
# Processing Record 30 of Set 8 | palkaka
# City not found. Skipping...
# Processing Record 31 of Set 8 | chokurdakh
# Processing Record 32 of Set 8 | camacha
# Processing Record 33 of Set 8 | jaisalmer
# Processing Record 34 of Set 8 | hami
# Processing Record 35 of Set 8 | strai
# Processing Record 36 of Set 8 | ko samui
# Processing Record 37 of Set 8 | nantucket
# Processing Record 38 of Set 8 | kijang
# Processing Record 39 of Set 8 | labuhan
# Processing Record 40 of Set 8 | kanlagay
# Processing Record 41 of Set 8 | vila velha
# Processing Record 42 of Set 8 | baykit
# Processing Record 43 of Set 8 | qaqortoq
# Processing Record 44 of Set 8 | prince rupert
# Processing Record 45 of Set 8 | kerouane
# Processing Record 46 of Set 8 | mbinga
# Processing Record 47 of Set 8 | znamenskoye
# Processing Record 48 of Set 8 | kang
# Processing Record 49 of Set 8 | lufilufi
# Processing Record 50 of Set 8 | jamsa
# Processing Record 1 of Set 9 | mayo
# Processing Record 2 of Set 9 | tolstoy-yurt
# Processing Record 3 of Set 9 | silifke
# Processing Record 4 of Set 9 | varna
# Processing Record 5 of Set 9 | cobija
# Processing Record 6 of Set 9 | huautla
# Processing Record 7 of Set 9 | narsaq
# Processing Record 8 of Set 9 | francisco sa
# Processing Record 9 of Set 9 | severnyy
# Processing Record 10 of Set 9 | otofuke
# Processing Record 11 of Set 9 | puerto colombia
# Processing Record 12 of Set 9 | alto araguaia
# Processing Record 13 of Set 9 | gimli
# Processing Record 14 of Set 9 | golyshmanovo
# Processing Record 15 of Set 9 | outlook
# Processing Record 16 of Set 9 | juifang
# City not found. Skipping...
# Processing Record 17 of Set 9 | pangnirtung
# Processing Record 18 of Set 9 | krasnoyarsk
# Processing Record 19 of Set 9 | ofunato
# Processing Record 20 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 21 of Set 9 | yulara
# Processing Record 22 of Set 9 | kampot
# Processing Record 23 of Set 9 | upernavik
# Processing Record 24 of Set 9 | zhuhai
# Processing Record 25 of Set 9 | port blair
# Processing Record 26 of Set 9 | tat
# Processing Record 27 of Set 9 | buchanan
# Processing Record 28 of Set 9 | bonthe
# Processing Record 29 of Set 9 | plunge
# Processing Record 30 of Set 9 | sorong
# Processing Record 31 of Set 9 | mandalgovi
# Processing Record 32 of Set 9 | lazaro cardenas
# Processing Record 33 of Set 9 | zhezkazgan
# Processing Record 34 of Set 9 | moerai
# Processing Record 35 of Set 9 | minsk
# Processing Record 36 of Set 9 | bilma
# Processing Record 37 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 38 of Set 9 | linping
# Processing Record 39 of Set 9 | gewane
# Processing Record 40 of Set 9 | mugur-aksy
# Processing Record 41 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 9 | vila franca do campo
# Processing Record 43 of Set 9 | lalibela
# Processing Record 44 of Set 9 | gasa
# Processing Record 45 of Set 9 | fare
# Processing Record 46 of Set 9 | weiden
# Processing Record 47 of Set 9 | ararangua
# Processing Record 48 of Set 9 | college
# Processing Record 49 of Set 9 | ossora
# Processing Record 50 of Set 9 | north bend
# Processing Record 1 of Set 10 | shakawe
# Processing Record 2 of Set 10 | orlik
# Processing Record 3 of Set 10 | amaigbo
# Processing Record 4 of Set 10 | noumea
# Processing Record 5 of Set 10 | ayan
# Processing Record 6 of Set 10 | tubuala
# Processing Record 7 of Set 10 | sungaipenuh
# Processing Record 8 of Set 10 | springdale
# Processing Record 9 of Set 10 | saint-georges
# Processing Record 10 of Set 10 | kysyl-syr
# Processing Record 11 of Set 10 | wiwili
# Processing Record 12 of Set 10 | esmeraldas
# Processing Record 13 of Set 10 | nago
# Processing Record 14 of Set 10 | yarada
# Processing Record 15 of Set 10 | quelimane
# Processing Record 16 of Set 10 | sirjan
# Processing Record 17 of Set 10 | bandarbeyla
# Processing Record 18 of Set 10 | simao
# Processing Record 19 of Set 10 | namikupa
# Processing Record 20 of Set 10 | bambanglipuro
# Processing Record 21 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 22 of Set 10 | lensk
# Processing Record 23 of Set 10 | tevriz
# Processing Record 24 of Set 10 | brasileia
# Processing Record 25 of Set 10 | spassk-dalniy
# Processing Record 26 of Set 10 | baie-comeau
# Processing Record 27 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 28 of Set 10 | bonfim
# Processing Record 29 of Set 10 | pokosnoye
# Processing Record 30 of Set 10 | ballina
# Processing Record 31 of Set 10 | roma
# Processing Record 32 of Set 10 | gribanovskiy
# Processing Record 33 of Set 10 | iwanai
# Processing Record 34 of Set 10 | balabac
# Processing Record 35 of Set 10 | semey
# Processing Record 36 of Set 10 | taltal
# Processing Record 37 of Set 10 | tessalit
# Processing Record 38 of Set 10 | los llanos de aridane
# Processing Record 39 of Set 10 | iguape
# Processing Record 40 of Set 10 | akhmim
# Processing Record 41 of Set 10 | kualakapuas
# Processing Record 42 of Set 10 | egvekinot
# Processing Record 43 of Set 10 | chara
# Processing Record 44 of Set 10 | cabedelo
# Processing Record 45 of Set 10 | fallon
# Processing Record 46 of Set 10 | kagalnitskaya
# Processing Record 47 of Set 10 | maldonado
# Processing Record 48 of Set 10 | guantanamo
# Processing Record 49 of Set 10 | hualmay
# Processing Record 50 of Set 10 | sibolga
# Processing Record 1 of Set 11 | dauriya
# Processing Record 2 of Set 11 | kindu
# Processing Record 3 of Set 11 | kununurra
# Processing Record 4 of Set 11 | biltine
# Processing Record 5 of Set 11 | finschhafen
# Processing Record 6 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 11 | codrington
# Processing Record 8 of Set 11 | husavik
# Processing Record 9 of Set 11 | lasa
# Processing Record 10 of Set 11 | benton harbor
# Processing Record 11 of Set 11 | lodeynoye pole
# Processing Record 12 of Set 11 | barinas
# Processing Record 13 of Set 11 | la grande
# Processing Record 14 of Set 11 | cajamarca
# Processing Record 15 of Set 11 | puerto palomas
# Processing Record 16 of Set 11 | umm kaddadah
# Processing Record 17 of Set 11 | ostrovnoy
# Processing Record 18 of Set 11 | korem
# Processing Record 19 of Set 11 | ewa beach
# Processing Record 20 of Set 11 | otradnoye
# Processing Record 21 of Set 11 | salym
# Processing Record 22 of Set 11 | kingston
# Processing Record 23 of Set 11 | qui nhon
# Processing Record 24 of Set 11 | harper
# Processing Record 25 of Set 11 | nargana
# Processing Record 26 of Set 11 | umm lajj
# Processing Record 27 of Set 11 | ust-nera
# Processing Record 28 of Set 11 | banda aceh
# Processing Record 29 of Set 11 | rorvik
# Processing Record 30 of Set 11 | nhulunbuy
# Processing Record 31 of Set 11 | nadvoitsy
# Processing Record 32 of Set 11 | manado
# Processing Record 33 of Set 11 | baoning
# Processing Record 34 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 35 of Set 11 | quesnel
# Processing Record 36 of Set 11 | boyolangu
# Processing Record 37 of Set 11 | chernyshevskiy
# Processing Record 38 of Set 11 | morant bay
# Processing Record 39 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 40 of Set 11 | leshan
# Processing Record 41 of Set 11 | lubango
# Processing Record 42 of Set 11 | yeppoon
# Processing Record 43 of Set 11 | yanam
# Processing Record 44 of Set 11 | madang
# Processing Record 45 of Set 11 | vanavara
# Processing Record 46 of Set 11 | mount isa
# Processing Record 47 of Set 11 | druzhba
# Processing Record 48 of Set 11 | wasilla
# Processing Record 49 of Set 11 | bluefields
# Processing Record 50 of Set 11 | yangjiang
# Processing Record 1 of Set 12 | nevelsk
# Processing Record 2 of Set 12 | waling
# Processing Record 3 of Set 12 | borgarnes
# Processing Record 4 of Set 12 | mujiayingzi
# Processing Record 5 of Set 12 | sosnovo-ozerskoye
# Processing Record 6 of Set 12 | tahoua
# Processing Record 7 of Set 12 | villa vazquez
# City not found. Skipping...
# Processing Record 8 of Set 12 | cockburn town
# Processing Record 9 of Set 12 | kuli
# Processing Record 10 of Set 12 | hastings
# Processing Record 11 of Set 12 | hohhot
# Processing Record 12 of Set 12 | donskoy
# Processing Record 13 of Set 12 | isangel
# Processing Record 14 of Set 12 | arlit
# Processing Record 15 of Set 12 | trairi
# Processing Record 16 of Set 12 | puksoozero
# Processing Record 17 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 12 | gazanjyk
# Processing Record 19 of Set 12 | nalut
# Processing Record 20 of Set 12 | taksimo
# Processing Record 21 of Set 12 | miraflores
# Processing Record 22 of Set 12 | talcahuano
# Processing Record 23 of Set 12 | nanortalik
# Processing Record 24 of Set 12 | jijiga
# Processing Record 25 of Set 12 | san juan
# Processing Record 26 of Set 12 | muhororo
# Processing Record 27 of Set 12 | key biscayne
# Processing Record 28 of Set 12 | kenai
# Processing Record 29 of Set 12 | vila do maio
# Processing Record 30 of Set 12 | jining
# Processing Record 31 of Set 12 | syracuse
# Processing Record 32 of Set 12 | asau
# Processing Record 33 of Set 12 | kapit
# Processing Record 34 of Set 12 | nizhnyaya tura
# Processing Record 35 of Set 12 | buraydah
# Processing Record 36 of Set 12 | mudyuga
# City not found. Skipping...
# Processing Record 37 of Set 12 | chuy
# Processing Record 38 of Set 12 | baoro
# Processing Record 39 of Set 12 | belyy yar
# Processing Record 40 of Set 12 | dalby
# Processing Record 41 of Set 12 | clonakilty
# Processing Record 42 of Set 12 | sola
# Processing Record 43 of Set 12 | sao francisco de assis
# Processing Record 44 of Set 12 | tual
# Processing Record 45 of Set 12 | hirara
# Processing Record 46 of Set 12 | magistralnyy
# Processing Record 47 of Set 12 | svetlyy
# Processing Record 48 of Set 12 | krasnoselkup
# Processing Record 49 of Set 12 | yelan
# Processing Record 50 of Set 12 | brownsville
# Processing Record 1 of Set 13 | margate
# Processing Record 2 of Set 13 | thongwa
# Processing Record 3 of Set 13 | qiongshan
# Processing Record 4 of Set 13 | pedernales
# Processing Record 5 of Set 13 | paamiut
# Processing Record 6 of Set 13 | lar gerd
# City not found. Skipping...
# Processing Record 7 of Set 13 | mnogovershinnyy
# Processing Record 8 of Set 13 | bushehr
# Processing Record 9 of Set 13 | luancheng
# Processing Record 10 of Set 13 | te anau
# Processing Record 11 of Set 13 | marana
# Processing Record 12 of Set 13 | novyy urengoy
# Processing Record 13 of Set 13 | saint-leu
# Processing Record 14 of Set 13 | zandvoort
# Processing Record 15 of Set 13 | ngama
# Processing Record 16 of Set 13 | ivdel
# Processing Record 17 of Set 13 | pontianak
# Processing Record 18 of Set 13 | cedar city
# Processing Record 19 of Set 13 | puerto baquerizo moreno
# Processing Record 20 of Set 13 | gaomi
# Processing Record 21 of Set 13 | avera
# Processing Record 22 of Set 13 | pierre
# Processing Record 23 of Set 13 | port keats
# Processing Record 24 of Set 13 | faya
# Processing Record 25 of Set 13 | san carlos de bariloche
# Processing Record 26 of Set 13 | plettenberg bay
# Processing Record 27 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 28 of Set 13 | aljezur
# Processing Record 29 of Set 13 | tyrma
# Processing Record 30 of Set 13 | sibiti
# Processing Record 31 of Set 13 | hambantota
# Processing Record 32 of Set 13 | whitehorse
# Processing Record 33 of Set 13 | vostok
# Processing Record 34 of Set 13 | wajima
# Processing Record 35 of Set 13 | batagay
# Processing Record 36 of Set 13 | sicamous
# Processing Record 37 of Set 13 | atbasar
# Processing Record 38 of Set 13 | eureka
# Processing Record 39 of Set 13 | olafsvik
# Processing Record 40 of Set 13 | obo
# Processing Record 41 of Set 13 | saint-marc
# Processing Record 42 of Set 13 | uyuni
# Processing Record 43 of Set 13 | sao felix do xingu
# Processing Record 44 of Set 13 | shingu
# Processing Record 45 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 46 of Set 13 | trofors
# Processing Record 47 of Set 13 | barabai
# Processing Record 48 of Set 13 | sarangani
# Processing Record 49 of Set 13 | sembe
# Processing Record 50 of Set 13 | key west
# Processing Record 1 of Set 14 | ferrara
# Processing Record 2 of Set 14 | billings
# Processing Record 3 of Set 14 | bakchar
# Processing Record 4 of Set 14 | palencia
# Processing Record 5 of Set 14 | inhambane
# Processing Record 6 of Set 14 | lilongwe
# Processing Record 7 of Set 14 | shelburne
# Processing Record 8 of Set 14 | samarai
# Processing Record 9 of Set 14 | casablanca
# Processing Record 10 of Set 14 | forest grove
# Processing Record 11 of Set 14 | aranos
# Processing Record 12 of Set 14 | igarka
# Processing Record 13 of Set 14 | oakdale
# Processing Record 14 of Set 14 | almeirim
# Processing Record 15 of Set 14 | mao
# Processing Record 16 of Set 14 | mana
# Processing Record 17 of Set 14 | mastung
# Processing Record 18 of Set 14 | kathu
# Processing Record 19 of Set 14 | meghri
# Processing Record 20 of Set 14 | chumikan
# Processing Record 21 of Set 14 | bilibino
# Processing Record 22 of Set 14 | menongue
# Processing Record 23 of Set 14 | nouakchott
# Processing Record 24 of Set 14 | chapais
# Processing Record 25 of Set 14 | henties bay
# Processing Record 26 of Set 14 | saint anthony
# Processing Record 27 of Set 14 | stykkisholmur
# Processing Record 28 of Set 14 | miranda
# Processing Record 29 of Set 14 | tukrah
# Processing Record 30 of Set 14 | nichinan
# Processing Record 31 of Set 14 | arman
# Processing Record 32 of Set 14 | sioux lookout
# Processing Record 33 of Set 14 | nampula
# Processing Record 34 of Set 14 | roald
# Processing Record 35 of Set 14 | nuzvid
# Processing Record 36 of Set 14 | mizque
# Processing Record 37 of Set 14 | najran
# Processing Record 38 of Set 14 | yerofey pavlovich
# Processing Record 39 of Set 14 | washington
# Processing Record 40 of Set 14 | bani
# Processing Record 41 of Set 14 | puerto cabezas
# Processing Record 42 of Set 14 | rawson
# Processing Record 43 of Set 14 | korla
# Processing Record 44 of Set 14 | bo rai
# Processing Record 45 of Set 14 | huntington
# Processing Record 46 of Set 14 | dunedin
# Processing Record 47 of Set 14 | hovd
# Processing Record 48 of Set 14 | tautira
# Processing Record 49 of Set 14 | moen
# Processing Record 50 of Set 14 | broken hill
# Processing Record 1 of Set 15 | savonlinna
# Processing Record 2 of Set 15 | kirovsk
# Processing Record 3 of Set 15 | manacapuru
# Processing Record 4 of Set 15 | wagar
# Processing Record 5 of Set 15 | de-kastri
# Processing Record 6 of Set 15 | sinnamary
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
updated_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[updated_column_order]
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0          Luau      AO  2021-10-11 23:32:37 -10.7073   22.2247     72.03
# 1       Aklavik      CA  2021-10-11 23:30:36  68.2191 -135.0107     30.92
# 2         Kapaa      US  2021-10-11 23:27:30  22.0752 -159.3190     84.52
# 3  Oktyabrskoye      RU  2021-10-11 23:32:37  43.0645   44.7417     35.74
# 4      Victoria      HK  2021-10-11 23:30:25  22.2855  114.1577     77.25
# 5        Darhan      MN  2021-10-11 23:32:38  49.4867  105.9228     39.90
# 6   Provideniya      RU  2021-10-11 23:30:37  64.3833 -173.3000     32.11
# 7         Pisco      PE  2021-10-11 23:25:45 -13.7000  -76.2167     62.65
# 8     Moramanga      MG  2021-10-11 23:32:38 -18.9333   48.2000     55.94
# 9      Cherskiy      RU  2021-10-11 23:30:49  68.7500  161.3000      7.70
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        64         100        0.60     overcast clouds
# 1        78          97       10.13     overcast clouds
# 2        66          40        4.00    scattered clouds
# 3       100           1        6.71                mist
# 4        74          96        1.99          light rain
# 5        48          77        5.12       broken clouds
# 6        74          75        4.47       broken clouds
# 7        82          40       17.27    scattered clouds
# 8        99          68        2.80       broken clouds
# 9        92          35        2.57    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
